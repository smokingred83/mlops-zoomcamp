# %%
from mlflow.entities import ViewType
import mlflow

mlflow.set_tracking_uri("sqlite:///homework.db")
exp = mlflow.set_experiment("random-forest-best-models")
runs = mlflow.search_runs(
    experiment_ids=exp.experiment_id,
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=3,
    order_by=["parameter.rmse_test ASC"]
)
runs
# Out:
#                              run_id experiment_id    status  \
# 0  12ff0abaaae14f67a66c542f65ae8b64             3  FINISHED
# 1  dff782b6711944ac81e43ffdf01f0989             3  FINISHED
# 2  e849cf3bcd314ef9b2a9cd2e20e36b58             3  FINISHED
#
#                                         artifact_uri  \
# 0  file:C:/repos/mlops-zoomcamp/02-experiment-tra...
# 1  file:C:/repos/mlops-zoomcamp/02-experiment-tra...
# 2  file:C:/repos/mlops-zoomcamp/02-experiment-tra...
#
#                         start_time                         end_time  \
# 0 2026-06-18 18:53:39.248000+00:00 2026-06-18 18:54:08.300000+00:00
# 1 2026-06-18 18:54:51.535000+00:00 2026-06-18 18:55:08.056000+00:00
# 2 2026-06-18 18:54:08.337000+00:00 2026-06-18 18:54:25.112000+00:00
#
#      params.rmse_val   params.rmse_test  tags.mlflow.runName  \
# 0  5.351836786271211  5.598103326486056  incongruous-yak-908
# 1  5.374487291865322  5.609792848403917  resilient-chimp-773
# 2   5.37222325598513  5.611054970402071          fun-cub-767
#
#               tags.mlflow.source.git.commit tags.mlflow.source.type  \
# 0  f2a927c0b7b9fd955de777d8dcf581f7160aee18                   LOCAL
# 1  f2a927c0b7b9fd955de777d8dcf581f7160aee18                   LOCAL
# 2  f2a927c0b7b9fd955de777d8dcf581f7160aee18                   LOCAL
#
#   tags.mlflow.source.name tags.mlflow.user
# 0     .\register_model.py        Giancarlo
# 1     .\register_model.py        Giancarlo
# 2     .\register_model.py        Giancarlo
